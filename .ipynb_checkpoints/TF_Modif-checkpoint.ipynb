# %%
import torch
import torch.optim as optim
import torch.nn as nn
import torch.nn.functional as F

import math

import time
import numpy as np
from speech2affective_gestures.net.utils.graph import Graph
from speech2affective_gestures.net.utils.tgcn import STGraphConv, STGraphConvTranspose
import shutil

import librosa
from librosa.feature import mfcc
import numpy as np
from scipy.interpolate import interp1d
from sklearn.preprocessing import normalize

import random


# In[2]:

print("Script started...")

from Model_Components.m2ad_beat_generator_net import Seq2SeqGenerator

encoder_args = {
    'hidden_size':256,
    'n_layers':3,
    'dropout_prob':0.4
}

decoder_args = {
    'hidden_size':256,
    'n_layers':3,
    'dropout_prob':0.4
}

device = 'cuda'

in_shape = torch.rand(8,20,51)

s2s = Seq2SeqGenerator(encoder_args, decoder_args, 440, 37, 440, 12, 2, 20).to(device=device)
s2s.load_state_dict(torch.load('./s2s_AIST.pth'))
for params in s2s.parameters():
    params.requires_grad = False
s2s.eval()
# Out:
# Script started...
# Seq2SeqGenerator(
#   (encoder): PoseEncoder(
#     (audio_encoder): MFCCEncoder(
#       (conv1): Conv1d(440, 64, kernel_size=(5,), stride=(1,), padding=(2,))
#       (batch_norm1): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv1d(64, 48, kernel_size=(5,), stride=(1,), padding=(2,))
#       (batch_norm2): BatchNorm1d(48, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv1d(48, 20, kernel_size=(3,), stride=(1,), padding=(1,))
#       (batch_norm3): BatchNorm1d(20, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (linear1): Linear(in_features=37, out_features=32, bias=True)
#       (activation): LeakyReLU(negative_slope=0.3, inplace=True)
#     )
#     (chroma_encoder): ChromaEncoder(
#       (conv1): Conv1d(440, 64, kernel_size=(5,), stride=(1,), padding=(2,))
#       (batch_norm1): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv1d(64, 48, kernel_size=(5,), stride=(1,), padding=(2,))
#       (batch_norm2): BatchNorm1d(48, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv1d(48, 20, kernel_size=(3,), stride=(1,), padding=(1,))
#       (batch_norm3): BatchNorm1d(20, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (linear1): Linear(in_features=12, out_features=4, bias=True)
#       (activation): LeakyReLU(negative_slope=0.3, inplace=True)
#     )
#     (aff_encoder): AffEncoder(
#       (st_gcn1): STGraphConv(
#         (gcn): ConvTemporalGraphical(
#           (conv): Conv2d(3, 80, kernel_size=(9, 1), stride=(1, 1), padding=(4, 0))
#         )
#         (tcn): Sequential(
#           (0): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (1): ReLU(inplace=True)
#           (2): Conv2d(16, 16, kernel_size=(9, 5), stride=(1, 1), padding=(4, 2))
#           (3): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (4): Dropout(p=0, inplace=True)
#         )
#         (residual): Sequential(
#           (0): Conv2d(3, 16, kernel_size=(1, 1), stride=(1, 1))
#           (1): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (activation): LeakyReLU(negative_slope=0.01, inplace=True)
#       )
#       (batch_norm1): BatchNorm1d(272, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (st_gcn2): STGraphConv(
#         (gcn): ConvTemporalGraphical(
#           (conv): Conv2d(64, 80, kernel_size=(9, 1), stride=(1, 1), padding=(4, 0))
#         )
#         (tcn): Sequential(
#           (0): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (1): ReLU(inplace=True)
#           (2): Conv2d(16, 16, kernel_size=(9, 3), stride=(1, 1), padding=(4, 1))
#           (3): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (4): Dropout(p=0, inplace=True)
#         )
#         (residual): Sequential(
#           (0): Conv2d(64, 16, kernel_size=(1, 1), stride=(1, 1))
#           (1): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (activation): LeakyReLU(negative_slope=0.01, inplace=True)
#       )
#       (batch_norm2): BatchNorm1d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv1d(96, 16, kernel_size=(5,), stride=(1,), padding=(2,))
#       (batch_norm3): BatchNorm1d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv4): Conv1d(16, 16, kernel_size=(3,), stride=(1,), padding=(1,))
#       (batch_norm4): BatchNorm1d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (activation): LeakyReLU(negative_slope=0.01, inplace=True)
#     )
#     (lstm): LSTM(52, 256, num_layers=3, batch_first=True, dropout=0.4)
#   )
#   (decoder): PoseDecoder(
#     (aff_encoder): AffEncoder(
#       (st_gcn1): STGraphConv(
#         (gcn): ConvTemporalGraphical(
#           (conv): Conv2d(3, 80, kernel_size=(9, 1), stride=(1, 1), padding=(4, 0))
#         )
#         (tcn): Sequential(
#           (0): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (1): ReLU(inplace=True)
#           (2): Conv2d(16, 16, kernel_size=(9, 5), stride=(1, 1), padding=(4, 2))
#           (3): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (4): Dropout(p=0, inplace=True)
#         )
#         (residual): Sequential(
#           (0): Conv2d(3, 16, kernel_size=(1, 1), stride=(1, 1))
#           (1): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (activation): LeakyReLU(negative_slope=0.01, inplace=True)
#       )
#       (batch_norm1): BatchNorm1d(272, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (st_gcn2): STGraphConv(
#         (gcn): ConvTemporalGraphical(
#           (conv): Conv2d(64, 80, kernel_size=(9, 1), stride=(1, 1), padding=(4, 0))
#         )
#         (tcn): Sequential(
#           (0): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (1): ReLU(inplace=True)
#           (2): Conv2d(16, 16, kernel_size=(9, 3), stride=(1, 1), padding=(4, 1))
#           (3): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (4): Dropout(p=0, inplace=True)
#         )
#         (residual): Sequential(
#           (0): Conv2d(64, 16, kernel_size=(1, 1), stride=(1, 1))
#           (1): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (activation): LeakyReLU(negative_slope=0.01, inplace=True)
#       )
#       (batch_norm2): BatchNorm1d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv1d(96, 16, kernel_size=(5,), stride=(1,), padding=(2,))
#       (batch_norm3): BatchNorm1d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv4): Conv1d(16, 16, kernel_size=(3,), stride=(1,), padding=(1,))
#       (batch_norm4): BatchNorm1d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (activation): LeakyReLU(negative_slope=0.01, inplace=True)
#     )
#     (lstm): LSTM(16, 256, num_layers=3, batch_first=True, dropout=0.4)
#     (out): Sequential(
#       (0): Linear(in_features=256, out_features=128, bias=True)
#       (1): LeakyReLU(negative_slope=0.01, inplace=True)
#       (2): Linear(in_features=128, out_features=51, bias=True)
#     )
#   )
# )

# %%
from torch.utils.data import Dataset, DataLoader

with open('./AIST_Train_data_with_root.npy','rb') as f:
    mfcc_files = np.load(f)
    chroma_files = np.load(f)
    sc_files = np.load(f)
    beats_files = np.load(f,allow_pickle=True)
    seq_names = np.load(f)
    target_pose_vecs = np.load(f)
    target_pose_vertices = np.load(f)
    target_labels = np.load(f)
    root_properties_data = np.load(f)
    
class CustomGANDataset(Dataset):

    def __init__(self,mfcc_files,chroma_files,sc_files,beats_files,target_pose_vecs,target_labels, s2s, seq_names):
        self.mfcc_files = mfcc_files
        self.chroma_files = chroma_files
        self.sc_files = sc_files
        self.beats_files = beats_files
        self.target_pose_vecs = target_pose_vecs
        self.target_labels = target_labels
        self.s2s_model = s2s

        self.seq_names = seq_names


    def __len__(self):
        return len(beats_files)

    def __getitem__(self, idx):

        mfcc_in = self.mfcc_files[idx]
        chroma_in = self.chroma_files[idx]
        sc_in = self.sc_files[idx]
        label_in = self.target_labels[idx].astype(np.int32) - 1
        label_in = label_in.reshape(1)

        beat_target_pose_in = self.get_beat_poses(idx)
        target_pose_in = self.target_pose_vecs[idx]

        pre_seq = self.generate_pre_seq(beat_target_pose_in, mfcc_in, chroma_in, label_in, idx)

        seq_name = self.seq_names[idx]


        return pre_seq.astype(np.float32), target_pose_in.astype(np.float32), mfcc_in.astype(np.float32), chroma_in.astype(np.float32), label_in, seq_name

    def get_beat_poses(self,idx):

        target_pose_in = self.target_pose_vecs[idx]
        beats = self.beats_files[idx]

        beat_poses = []

        for time_stamp in beats[:20]:
            frame_val = np.round(time_stamp,2) * 60
            index = int(frame_val//6)
            beat_poses.append(target_pose_in[int(index)])

        temp_frames = np.zeros((20,51))

        temp_frames[:len(beat_poses)] = np.array(beat_poses)

        return temp_frames

    def generate_pre_seq(self, beat_target_pose_in, mfcc_in, chroma_in, label_in, idx):

        beat_target_pose_in = torch.from_numpy(beat_target_pose_in).unsqueeze(0).to(device=device)
        mfcc_in = torch.from_numpy(mfcc_in).unsqueeze(0).to(device=device)
        chroma_in = torch.from_numpy(chroma_in).unsqueeze(0).to(device=device)
        label_in = torch.from_numpy(label_in).unsqueeze(0).to(device=device)

        pre_seq = beat_target_pose_in.new_zeros((beat_target_pose_in.shape[0], beat_target_pose_in.shape[1],
                                            beat_target_pose_in.shape[2] + 1))
        pre_seq[:, 0:3, :-1] = beat_target_pose_in[:, 0:3]
        pre_seq[:, 0:3, -1] = 1  

        teacher_force_ratio = 0

        self.s2s_model.eval()
        with torch.no_grad():
            outputs = self.s2s_model(pre_seq, mfcc_in, chroma_in, label_in,beat_target_pose_in, teacher_force_ratio)
        
        # How to remap outputs back to original

        outputs = outputs.squeeze(0).detach().cpu().numpy()
        beats = self.beats_files[idx]
        target_pose_in = self.target_pose_vecs[idx]


        pre_seq = np.zeros((100,51))

        pre_seq[:20] = target_pose_in[:20]
        

        beat_counter = 0
        for time_stamp in beats[:20]:
            
            frame_val = np.round(time_stamp,2) * 60
            index = int(frame_val//6)

            if index >20:
                pre_seq[index] = outputs[beat_counter]
                
            beat_counter+=1

        constraint_bit = np.ones((100,1))

        pre_seq = np.hstack((pre_seq, constraint_bit))

        return pre_seq

# %%
def check_for_nan(pre_seq, target_pose_in, mfcc_in, chroma_in):
    pre_seq_check = np.isfinite(pre_seq).all()
    target_pose_in_check = np.isfinite(target_pose_in).all()
    mfcc_in_check = np.isfinite(mfcc_in).all()
    chroma_in_check = np.isfinite(chroma_in).all()

    if pre_seq_check == False or target_pose_in_check == False or mfcc_in_check == False or chroma_in_check == False:
        print("INF in dataset")

# %%
gan_data = CustomGANDataset(mfcc_files,chroma_files,sc_files,beats_files,target_pose_vecs,target_labels, s2s.to(device=device), seq_names)

training_processed_data = []

for idx, (pre_seq, target_pose_in, mfcc_in, chroma_in, label_in, seq_name) in enumerate(gan_data):
    check_for_nan(pre_seq, target_pose_in, mfcc_in, chroma_in)
    training_processed_data.append(gan_data[idx])

    train_dataloader = DataLoader(training_processed_data, batch_size=8, shuffle=True)

# %%
# ## Loss Functions

# In[5]:


# Direction Vectors
#right-knee = 5-6 should be index [15:18] 
#right-shin = 6-7 should be index [18:21]
#left-knee = 11-12 should be index [21:24]
#left-shin = 12-13 should be index [24:27]

def get_leg_loss(out,target):
    loss_func = torch.nn.SmoothL1Loss(size_average=None, reduce=None, reduction='mean', beta=5.0)
    error = 0.
    for _ in range(out.shape[0]):
        
        right_femur_out_actual = out[_][15:18] * 10
        right_shin_out_actual = out[_][18:21] * 10
        right_femur_target = target[_][15:18] * 10
        right_shin_target = target[_][18:21] * 10
        
        with torch.no_grad():
            non_diff_right_femur_out = torch.round(right_femur_out_actual,decimals=2).to(device)
            non_diff_right_shin_out = torch.round(right_shin_out_actual,decimals=2).to(device)

            difference_right_femur = right_femur_out_actual - non_diff_right_femur_out
            difference_right_shin = right_shin_out_actual - non_diff_right_shin_out 

        right_femur_out = right_femur_out_actual - difference_right_femur
        right_shin_out = right_shin_out_actual - difference_right_shin

        mag_right_femur = torch.linalg.norm(right_femur_out)
        mag_right_shin = torch.linalg.norm(right_shin_out)
        
        angle_val = (torch.dot(right_femur_out,right_shin_out))/(mag_right_femur*mag_right_shin)
        out_right_angle = 2
        if angle_val<=1 and angle_val>=-1:
            out_right_angle = torch.acos(angle_val)
            
        mag_right_femur = torch.linalg.norm(right_femur_target)
        mag_right_shin = torch.linalg.norm(right_shin_target)

        target_right_angle = torch.acos((torch.dot(right_femur_target,right_shin_target))/(mag_right_femur*mag_right_shin))
            
        left_femur_out_actual = out[_][21:24] * 10
        left_shin_out_actual = out[_][24:27] * 10
        left_femur_target = target[_][21:24] * 10
        left_shin_target = target[_][24:27] * 10
        
        with torch.no_grad():
            non_diff_left_femur_out = torch.round(left_femur_out_actual,decimals=2).to(device)
            non_diff_left_shin_out = torch.round(left_shin_out_actual,decimals=2).to(device)

            difference_left_femur = left_femur_out_actual - non_diff_left_femur_out
            difference_left_shin = left_shin_out_actual - non_diff_left_shin_out 

        left_femur_out = left_femur_out_actual - difference_left_femur
        left_shin_out = left_shin_out_actual - difference_left_shin

        mag_left_femur = torch.linalg.norm(left_femur_out)
        mag_left_shin = torch.linalg.norm(left_shin_out)
        
        angle_val = (torch.dot(left_femur_out,left_shin_out))/(mag_left_femur*mag_left_shin)
        out_left_angle = 2
        if angle_val<=1 and angle_val>=-1:
            out_left_angle = torch.acos(angle_val)

        mag_left_femur = torch.linalg.norm(left_femur_target)
        mag_left_shin = torch.linalg.norm(left_shin_target)
        
        target_left_angle = torch.acos((torch.dot(left_femur_target,left_shin_target))/(mag_left_femur*mag_left_shin))

        if type(out_left_angle) is int or type(out_right_angle) is int:
            print("Invalid loss here")
            print(out_left_angle)
            print(out_right_angle)
            print(angle_val)
            print(left_femur_out)
            print(left_shin_out)
            print(right_femur_out)
            print(right_shin_out)

            out_left_angle = prev_out_left_anlge
            out_right_angle = prev_out_right_angle
        #Smooth L1
        output_vals_mat = torch.hstack((out_right_angle,out_left_angle))/100

        # target_vals_mat = torch.from_numpy(np.array([target_right_angle,target_left_angle])/100).to(device='cuda')
        target_vals_mat = torch.hstack((target_right_angle,target_left_angle))/100
        error+= 0.3 * loss_func(output_vals_mat,target_vals_mat)
        
        #ALSO DO SOME KIND OF ANGULAR VELOCITY LOSS
        
        if _ == 0:
            prev_out_left_anlge = out_left_angle
            prev_out_right_angle = out_right_angle
            
            prev_target_left_angle = target_left_angle
            prev_target_right_angle = target_right_angle

        
        else:
            # This is second index. Track the angular velocity i.e current angle - prev angle and get a loss
            # and make this the more dominant loss
            
            delta_out_left = out_left_angle - prev_out_left_anlge
            delta_out_right = out_right_angle - prev_out_right_angle
            
            delta_target_left = target_left_angle - prev_target_left_angle
            delta_target_right = target_right_angle - prev_target_right_angle
            
            # output_vals_mat = torch.from_numpy(np.array([delta_out_left,delta_out_right])/100).to(device='cuda')
            # target_vals_mat = torch.from_numpy(np.array([delta_target_left,delta_target_right])/100).to(device='cuda')

            output_vals_mat = torch.hstack((delta_out_left,delta_out_right))/100
            target_vals_mat = torch.hstack((delta_target_left,delta_target_right))/100
            
            error+= 0.7 * loss_func(output_vals_mat,target_vals_mat)
        
            prev_out_left_anlge = out_left_angle
            prev_out_right_angle = out_right_angle
            
            prev_target_left_angle = target_left_angle
            prev_target_right_angle = target_right_angle
        
        
    return error/100


# In[6]:


def get_velocity_loss(outputs, targets, loss_function): #will be defined as movement of poses from time1-time0, time2-time1, time3-time2 etc.

    batch_size, time_steps, pose_dim = outputs.shape

    total_loss = 0.

    for item in range(batch_size):
        out = outputs[item]
        target = targets[item]
        
        leg_loss = 0.
        leg_loss = get_leg_loss(out,target)

        non_zero_out = out
        non_zero_target = target

        out_1d = non_zero_out[2:] - non_zero_out[1:-1]
        target_1d = non_zero_target[2:] - non_zero_target[1:-1]

        v_loss = loss_function(out_1d, target_1d)
        p_loss = loss_function(non_zero_out, non_zero_target)

        total_loss += v_loss
        total_loss += p_loss
        total_loss += 0.3*leg_loss

    return total_loss


# In[7]:


def forward_pass_s2ag(in_mfcc, in_chroma, label_in, pre_seq, target_poses, s2ag_generator, s2ag_discriminator, s2ag_gen_optimizer, s2ag_dis_optimizer, tf_ratio):

    # make pre seq input
    # pre_seq = target_poses.new_zeros((target_poses.shape[0], target_poses.shape[1],
    #                                     target_poses.shape[2] + 1))
    # pre_seq[:, 0:20, :-1] = target_poses[:, 0:20]
    # pre_seq[:, 0:20, -1] = 1  # indicating bit for constraints

    ###########################################################################################
    # train D
    dis_error = None

    s2ag_dis_optimizer.zero_grad()

    # out shape (batch x seq x dim)
    # s2s -> self, pre_seq, in_mfcc, in_chroma, label_val, target, teacher_force_ratio

    out_dir_vec = s2ag_generator(pre_seq, in_mfcc, in_chroma, label_in,target_poses, tf_ratio)
    print(out_dir_vec.shape)


    dis_real = s2ag_discriminator(target_poses, label_in)



    dis_fake = s2ag_discriminator(out_dir_vec.detach(), label_in)



    dis_error = torch.sum(-torch.mean(torch.log(dis_real + 1e-8) + torch.log(1 - dis_fake + 1e-8)))  # ns-gan

    dis_error.backward()
    s2ag_dis_optimizer.step()

    ###########################################################################################
    # train G

    for _ in range(5):
        s2ag_gen_optimizer.zero_grad()

        # decoding

        out_dir_vec = s2ag_generator(pre_seq, in_mfcc, in_chroma, label_in,target_poses, tf_ratio)



        # loss
        beta = 0.1
        # huber_loss = F.smooth_l1_loss(out_dir_vec / beta, target_poses / beta) * beta
        
        #Define huber loss as the velocity loss thing
        loss_function = torch.nn.SmoothL1Loss()
        huber_loss = get_velocity_loss(out_dir_vec, target_poses, loss_function)


        dis_output = s2ag_discriminator(out_dir_vec, label_in)
        gen_error = -torch.mean(torch.log(dis_output + 1e-8))
        kld = div_reg = None

        loss_regression_weight = 500
        loss_gan_weight = 5.0

        loss = loss_regression_weight * huber_loss  # + var_loss

        loss += loss_gan_weight * gen_error

        loss.backward()
        s2ag_gen_optimizer.step()

    return F.l1_loss(out_dir_vec, target_poses).item(), dis_error.item(), loss.item() 


# In[8]:


def per_train_epoch(s2ag_generator, s2ag_discriminator, s2ag_gen_optimizer, s2ag_dis_optimizer, tf_ratio):

    s2ag_generator.train()
    s2ag_discriminator.train()
         
    batch_s2ag_loss = 0.

    dis_loss = 0.
    gen_loss = 0.

    # Use batch size of 8

    num_batches = len(train_dataloader)

    start_time = time.time()

    # Make a batch loop here

    for batch_idx, (pre_pose_vecs, target_pose_vecs, train_mfccs, train_chromas, train_labels, seq_name) in enumerate(train_dataloader):


        loss, dis_error, gen_error = forward_pass_s2ag(train_mfccs.to(device=device),train_chromas.to(device=device),train_labels.to(device=device),pre_pose_vecs.to(device=device),                                 target_pose_vecs.to(device=device),                                 s2ag_generator, s2ag_discriminator, s2ag_gen_optimizer, s2ag_dis_optimizer, tf_ratio)
        # Compute statistics
        batch_s2ag_loss += loss

        dis_loss+=dis_error
        gen_loss+=gen_error

        print("Batch: {}/{}, Time per batch: {}".format(batch_idx,num_batches,int(np.ceil(time.time() - start_time))))
    

    batch_s2ag_loss /= num_batches

    dis_loss /=num_batches
    gen_loss /= num_batches

    print("Mean batch loss: {}, Dis loss: {}, Gen loss: {}".format(batch_s2ag_loss, dis_loss, gen_loss))


# In[9]:

# %%
from Model_Components.m2ad_pose_repletion_net import PoseSeq2SeqGenerator, AffDiscriminator

encoder_args = {
    'hidden_size':256,
    'n_layers':5,
    'dropout_prob':0.4
}

decoder_args = {
    'hidden_size':256,
    'n_layers':5,
    'dropout_prob':0.4
}
device = 'cuda'
s2ag_generator = PoseSeq2SeqGenerator(encoder_args, decoder_args, 440, 37, 440, 12, 2, 100).to(device=device)
s2ag_discriminator = AffDiscriminator(2,100, 16).to(device=device)

# %%
# s2ag_generator.load_state_dict(torch.load('./BN_RN_TFModif/M2AD_Gen11_ep20_10FPS'))
# s2ag_discriminator.load_state_dict(torch.load('./BN_RN_TFModif/M2AD_Disc11_ep20_10FPS'))

# %%
def train(s2ag_generator,s2ag_discriminator):

    s2ag_start_epoch = 0

    lr_s2ag_gen = 1e-3
    lr_s2ag_dis = 1e-5

    # s2ag optimizers
    s2ag_gen_optimizer = optim.Adam(s2ag_generator.parameters(),
                                            lr=lr_s2ag_gen, 
                                    betas=(0.5, 0.999)
                                    )

    s2ag_dis_optimizer = torch.optim.Adam(
        s2ag_discriminator.parameters(),
        lr=lr_s2ag_dis,
        betas=(0.5, 0.999)
        )
    
    tf_ratio = 1.0

    for epoch in range(s2ag_start_epoch, 500):

        if tf_ratio>0.5:
            if epoch%20 == 0 and epoch <100 and epoch >0:
                tf_ratio -=0.1

            elif epoch%40 ==0 and epoch >= 100 and tf_ratio>0:
                tf_ratio -=0.1

        if epoch%100 == 0 and epoch >= 300:

            lr_s2ag_gen /= 5
            lr_s2ag_dis /= 5

            # s2ag optimizers
            s2ag_gen_optimizer = optim.Adam(s2ag_generator.parameters(),
                                                    lr=lr_s2ag_gen, 
                                            betas=(0.5, 0.999)
                                            )

            s2ag_dis_optimizer = torch.optim.Adam(
                s2ag_discriminator.parameters(),
                lr=lr_s2ag_dis,
                betas=(0.5, 0.999)
                )

        # training
        print('s2ag training epoch: {}'.format(epoch))
        per_train_epoch(s2ag_generator,s2ag_discriminator,s2ag_gen_optimizer,s2ag_dis_optimizer, tf_ratio)
        print('Done.')
        

        # save model and weights
        
        if epoch%10 == 0:
            torch.save(s2ag_generator.state_dict(), './BN_RN_TFModif/M2AD_Gen11_ep'+str(epoch)+'_10FPS')
            torch.save(s2ag_discriminator.state_dict(), './BN_RN_TFModif/M2AD_Disc11_ep'+str(epoch)+'_10FPS')

# %%
print("Training started...")
train(s2ag_generator,s2ag_discriminator)
# Out:
# Training started...
# s2ag training epoch: 0
# torch.Size([8, 100, 51])
# Batch: 0/107, Time per batch: 5
# torch.Size([8, 100, 51])
# Batch: 1/107, Time per batch: 9
# torch.Size([8, 100, 51])
# Batch: 2/107, Time per batch: 13
# torch.Size([8, 100, 51])
# Batch: 3/107, Time per batch: 17
# torch.Size([8, 100, 51])
# Batch: 4/107, Time per batch: 21
# torch.Size([8, 100, 51])
# Batch: 5/107, Time per batch: 25
# torch.Size([8, 100, 51])
# Batch: 6/107, Time per batch: 29
# torch.Size([8, 100, 51])
# Batch: 7/107, Time per batch: 33
# torch.Size([8, 100, 51])
# Batch: 8/107, Time per batch: 37
# torch.Size([8, 100, 51])
# Batch: 9/107, Time per batch: 41
# torch.Size([8, 100, 51])
# Batch: 10/107, Time per batch: 45
# torch.Size([8, 100, 51])
# Batch: 11/107, Time per batch: 49
# torch.Size([8, 100, 51])
# Batch: 12/107, Time per batch: 53
# torch.Size([8, 100, 51])
# Batch: 13/107, Time per batch: 57
# torch.Size([8, 100, 51])
# Batch: 14/107, Time per batch: 61
# torch.Size([8, 100, 51])
# Batch: 15/107, Time per batch: 65
# torch.Size([8, 100, 51])
# Batch: 16/107, Time per batch: 69
# torch.Size([8, 100, 51])
# Batch: 17/107, Time per batch: 73
# torch.Size([8, 100, 51])
# Batch: 18/107, Time per batch: 77
# torch.Size([8, 100, 51])
# Batch: 19/107, Time per batch: 81
# torch.Size([8, 100, 51])
# Batch: 20/107, Time per batch: 85
# torch.Size([8, 100, 51])
# Batch: 21/107, Time per batch: 89
# torch.Size([8, 100, 51])
# Batch: 22/107, Time per batch: 93
# torch.Size([8, 100, 51])
# Batch: 23/107, Time per batch: 97
# torch.Size([8, 100, 51])
# Batch: 24/107, Time per batch: 101
# torch.Size([8, 100, 51])
# Batch: 25/107, Time per batch: 105
# torch.Size([8, 100, 51])
# Batch: 26/107, Time per batch: 109
# torch.Size([8, 100, 51])
# Batch: 27/107, Time per batch: 113
# torch.Size([8, 100, 51])
# Batch: 28/107, Time per batch: 117
# torch.Size([8, 100, 51])
# Batch: 29/107, Time per batch: 121
# torch.Size([8, 100, 51])
# Batch: 30/107, Time per batch: 125
# torch.Size([8, 100, 51])
# Batch: 31/107, Time per batch: 128
# torch.Size([8, 100, 51])
# Batch: 32/107, Time per batch: 132
# torch.Size([8, 100, 51])
# Batch: 33/107, Time per batch: 136
# torch.Size([8, 100, 51])
# Batch: 34/107, Time per batch: 140
# torch.Size([8, 100, 51])
# Batch: 35/107, Time per batch: 144
# torch.Size([8, 100, 51])
# Batch: 36/107, Time per batch: 148
# torch.Size([8, 100, 51])
# Batch: 37/107, Time per batch: 152
# torch.Size([8, 100, 51])
# Batch: 38/107, Time per batch: 156
# torch.Size([8, 100, 51])
# Batch: 39/107, Time per batch: 160
# torch.Size([8, 100, 51])
# Batch: 40/107, Time per batch: 164
# torch.Size([8, 100, 51])
# Batch: 41/107, Time per batch: 168
# torch.Size([8, 100, 51])
# Batch: 42/107, Time per batch: 172
# torch.Size([8, 100, 51])
# Batch: 43/107, Time per batch: 176
# torch.Size([8, 100, 51])
# Batch: 44/107, Time per batch: 180
# torch.Size([8, 100, 51])
# Batch: 45/107, Time per batch: 184
# torch.Size([8, 100, 51])
# Batch: 46/107, Time per batch: 188
# torch.Size([8, 100, 51])
# Batch: 47/107, Time per batch: 191
# torch.Size([8, 100, 51])
# Batch: 48/107, Time per batch: 195
# torch.Size([8, 100, 51])
# Batch: 49/107, Time per batch: 199
# torch.Size([8, 100, 51])
# Batch: 50/107, Time per batch: 203
# torch.Size([8, 100, 51])
# Batch: 51/107, Time per batch: 206
# torch.Size([8, 100, 51])
# Batch: 52/107, Time per batch: 210
# torch.Size([8, 100, 51])
# Batch: 53/107, Time per batch: 214
# torch.Size([8, 100, 51])
# Batch: 54/107, Time per batch: 218
# torch.Size([8, 100, 51])
# Batch: 55/107, Time per batch: 222
# torch.Size([8, 100, 51])
# Batch: 56/107, Time per batch: 225
# torch.Size([8, 100, 51])
# Batch: 57/107, Time per batch: 229
# torch.Size([8, 100, 51])
# Batch: 58/107, Time per batch: 233
# torch.Size([8, 100, 51])
# Batch: 59/107, Time per batch: 237
# torch.Size([8, 100, 51])
# Batch: 60/107, Time per batch: 241
# torch.Size([8, 100, 51])
# Batch: 61/107, Time per batch: 244
# torch.Size([8, 100, 51])
# Batch: 62/107, Time per batch: 248
# torch.Size([8, 100, 51])
# Batch: 63/107, Time per batch: 252
# torch.Size([8, 100, 51])
# Batch: 64/107, Time per batch: 256
# torch.Size([8, 100, 51])
# Batch: 65/107, Time per batch: 259
# torch.Size([8, 100, 51])
# Batch: 66/107, Time per batch: 263
# torch.Size([8, 100, 51])
# Batch: 67/107, Time per batch: 267
# torch.Size([8, 100, 51])
# Batch: 68/107, Time per batch: 271
# torch.Size([8, 100, 51])
# Batch: 69/107, Time per batch: 275
# torch.Size([8, 100, 51])
# Batch: 70/107, Time per batch: 278
# torch.Size([8, 100, 51])
# Batch: 71/107, Time per batch: 282
# torch.Size([8, 100, 51])
# Batch: 72/107, Time per batch: 286
# torch.Size([8, 100, 51])
# Batch: 73/107, Time per batch: 290
# torch.Size([8, 100, 51])
# Batch: 74/107, Time per batch: 294
# torch.Size([8, 100, 51])
# Batch: 75/107, Time per batch: 297
# torch.Size([8, 100, 51])
# Batch: 76/107, Time per batch: 301
# torch.Size([8, 100, 51])
# Batch: 77/107, Time per batch: 305
# torch.Size([8, 100, 51])
# Batch: 78/107, Time per batch: 309
# torch.Size([8, 100, 51])
# Batch: 79/107, Time per batch: 313
# torch.Size([8, 100, 51])
# Batch: 80/107, Time per batch: 316
# torch.Size([8, 100, 51])
# Batch: 81/107, Time per batch: 320
# torch.Size([8, 100, 51])
# Batch: 82/107, Time per batch: 324
# torch.Size([8, 100, 51])
# Batch: 83/107, Time per batch: 328
# torch.Size([8, 100, 51])
# Batch: 84/107, Time per batch: 331
# torch.Size([8, 100, 51])
# Batch: 85/107, Time per batch: 335
# torch.Size([8, 100, 51])
# Batch: 86/107, Time per batch: 339
# torch.Size([8, 100, 51])
# Batch: 87/107, Time per batch: 343
# torch.Size([8, 100, 51])
# Batch: 88/107, Time per batch: 347
# torch.Size([8, 100, 51])
# Batch: 89/107, Time per batch: 350
# torch.Size([8, 100, 51])
# Batch: 90/107, Time per batch: 354
# torch.Size([8, 100, 51])
# Batch: 91/107, Time per batch: 358
# torch.Size([8, 100, 51])
# Batch: 92/107, Time per batch: 362
# torch.Size([8, 100, 51])
# Batch: 93/107, Time per batch: 365
# torch.Size([8, 100, 51])
# Batch: 94/107, Time per batch: 369
# torch.Size([8, 100, 51])
# Batch: 95/107, Time per batch: 373
# torch.Size([8, 100, 51])
# Batch: 96/107, Time per batch: 377
# torch.Size([8, 100, 51])
# Batch: 97/107, Time per batch: 380
# torch.Size([8, 100, 51])
# Batch: 98/107, Time per batch: 384
# torch.Size([8, 100, 51])
# Batch: 99/107, Time per batch: 388
# torch.Size([8, 100, 51])
# Batch: 100/107, Time per batch: 392
# torch.Size([8, 100, 51])
# Batch: 101/107, Time per batch: 396
# torch.Size([8, 100, 51])
# Batch: 102/107, Time per batch: 399
# torch.Size([8, 100, 51])
# Batch: 103/107, Time per batch: 403
# torch.Size([8, 100, 51])
# Batch: 104/107, Time per batch: 407
# torch.Size([8, 100, 51])
# Batch: 105/107, Time per batch: 411
# torch.Size([8, 100, 51])
# Batch: 106/107, Time per batch: 415
# Mean batch loss: 0.19242293130014546, Dis loss: 1.3862146239414392, Gen loss: 211.47728009090244
# Done.
# s2ag training epoch: 1
# torch.Size([8, 100, 51])
# Batch: 0/107, Time per batch: 4
# torch.Size([8, 100, 51])
# Batch: 1/107, Time per batch: 8
# torch.Size([8, 100, 51])
# Batch: 2/107, Time per batch: 12
# torch.Size([8, 100, 51])
# Batch: 3/107, Time per batch: 16
# torch.Size([8, 100, 51])
# Batch: 4/107, Time per batch: 19
# torch.Size([8, 100, 51])
# Batch: 5/107, Time per batch: 23
# torch.Size([8, 100, 51])
# Batch: 6/107, Time per batch: 27
# torch.Size([8, 100, 51])
# Batch: 7/107, Time per batch: 31
# torch.Size([8, 100, 51])
# Batch: 8/107, Time per batch: 35
# torch.Size([8, 100, 51])
# Batch: 9/107, Time per batch: 38
# torch.Size([8, 100, 51])
# Batch: 10/107, Time per batch: 42
# torch.Size([8, 100, 51])
# Batch: 11/107, Time per batch: 46
# torch.Size([8, 100, 51])
# Batch: 12/107, Time per batch: 50
# torch.Size([8, 100, 51])
# Batch: 13/107, Time per batch: 54
# torch.Size([8, 100, 51])
# Batch: 14/107, Time per batch: 57
# torch.Size([8, 100, 51])
# Batch: 15/107, Time per batch: 61
# torch.Size([8, 100, 51])
# Batch: 16/107, Time per batch: 65
# torch.Size([8, 100, 51])
# Batch: 17/107, Time per batch: 69
# torch.Size([8, 100, 51])
# Batch: 18/107, Time per batch: 73
# torch.Size([8, 100, 51])
# Batch: 19/107, Time per batch: 76
# torch.Size([8, 100, 51])
# Batch: 20/107, Time per batch: 80
# torch.Size([8, 100, 51])
# Batch: 21/107, Time per batch: 84
# torch.Size([8, 100, 51])
# Batch: 22/107, Time per batch: 88
# torch.Size([8, 100, 51])
# Batch: 23/107, Time per batch: 92
# torch.Size([8, 100, 51])
# Batch: 24/107, Time per batch: 96
# torch.Size([8, 100, 51])
# Batch: 25/107, Time per batch: 99
# torch.Size([8, 100, 51])
# Batch: 26/107, Time per batch: 103
# torch.Size([8, 100, 51])
# Batch: 27/107, Time per batch: 107
# torch.Size([8, 100, 51])
# Batch: 28/107, Time per batch: 111
# torch.Size([8, 100, 51])
# Batch: 29/107, Time per batch: 115
# torch.Size([8, 100, 51])
# Batch: 30/107, Time per batch: 119
# torch.Size([8, 100, 51])
# Batch: 31/107, Time per batch: 122
# torch.Size([8, 100, 51])
# Batch: 32/107, Time per batch: 126
# torch.Size([8, 100, 51])
# Batch: 33/107, Time per batch: 130
# torch.Size([8, 100, 51])
# Batch: 34/107, Time per batch: 134
# torch.Size([8, 100, 51])
# Batch: 35/107, Time per batch: 138
# torch.Size([8, 100, 51])
# Batch: 36/107, Time per batch: 142
# torch.Size([8, 100, 51])
# Batch: 37/107, Time per batch: 145
# torch.Size([8, 100, 51])
# Batch: 38/107, Time per batch: 149
# torch.Size([8, 100, 51])
# Batch: 39/107, Time per batch: 153
# torch.Size([8, 100, 51])
# Batch: 40/107, Time per batch: 157
# torch.Size([8, 100, 51])
# Batch: 41/107, Time per batch: 161
# torch.Size([8, 100, 51])
# Batch: 42/107, Time per batch: 165
# torch.Size([8, 100, 51])
# Batch: 43/107, Time per batch: 169
# torch.Size([8, 100, 51])
# Batch: 44/107, Time per batch: 172
# torch.Size([8, 100, 51])
# Batch: 45/107, Time per batch: 176
# torch.Size([8, 100, 51])
# Batch: 46/107, Time per batch: 180
# torch.Size([8, 100, 51])
# Batch: 47/107, Time per batch: 184
# torch.Size([8, 100, 51])
# Batch: 48/107, Time per batch: 188
# torch.Size([8, 100, 51])
# Batch: 49/107, Time per batch: 192
# torch.Size([8, 100, 51])
# Batch: 50/107, Time per batch: 195
# torch.Size([8, 100, 51])
# Batch: 51/107, Time per batch: 199
# torch.Size([8, 100, 51])
# Batch: 52/107, Time per batch: 203
# torch.Size([8, 100, 51])
# Batch: 53/107, Time per batch: 207
# torch.Size([8, 100, 51])
# Batch: 54/107, Time per batch: 211
# torch.Size([8, 100, 51])
# Batch: 55/107, Time per batch: 215
# torch.Size([8, 100, 51])
# Batch: 56/107, Time per batch: 218
# torch.Size([8, 100, 51])
# Batch: 57/107, Time per batch: 222
# torch.Size([8, 100, 51])
# Batch: 58/107, Time per batch: 226
# torch.Size([8, 100, 51])
# Batch: 59/107, Time per batch: 230
# torch.Size([8, 100, 51])
# Batch: 60/107, Time per batch: 234
# torch.Size([8, 100, 51])
# Batch: 61/107, Time per batch: 238
# torch.Size([8, 100, 51])
# Batch: 62/107, Time per batch: 241
# torch.Size([8, 100, 51])
# Batch: 63/107, Time per batch: 245
# torch.Size([8, 100, 51])
# Batch: 64/107, Time per batch: 249
# torch.Size([8, 100, 51])
# Batch: 65/107, Time per batch: 253
# torch.Size([8, 100, 51])
# Batch: 66/107, Time per batch: 257
# torch.Size([8, 100, 51])
# Batch: 67/107, Time per batch: 260
# torch.Size([8, 100, 51])
# Batch: 68/107, Time per batch: 264
# torch.Size([8, 100, 51])
# Batch: 69/107, Time per batch: 268
# torch.Size([8, 100, 51])
# Batch: 70/107, Time per batch: 272
# torch.Size([8, 100, 51])
# Batch: 71/107, Time per batch: 276
# torch.Size([8, 100, 51])
# Batch: 72/107, Time per batch: 279
# torch.Size([8, 100, 51])
# Batch: 73/107, Time per batch: 283
# torch.Size([8, 100, 51])
# Batch: 74/107, Time per batch: 287
# torch.Size([8, 100, 51])
# Batch: 75/107, Time per batch: 291
# torch.Size([8, 100, 51])
# Batch: 76/107, Time per batch: 295
# torch.Size([8, 100, 51])
# Batch: 77/107, Time per batch: 298
# torch.Size([8, 100, 51])
# Batch: 78/107, Time per batch: 302
# torch.Size([8, 100, 51])
# Invalid loss here
# tensor([ 0.1000, -0.0500, -0.9300], device='cuda:0', grad_fn=<SubBackward0>)
# tensor([ 0.1000, -0.0500, -0.9300], device='cuda:0', grad_fn=<SubBackward0>)
# tensor([-0.1300,  0.1100, -1.0000], device='cuda:0', grad_fn=<SubBackward0>)
# tensor([-0.1900,  0.1100, -0.8700], device='cuda:0', grad_fn=<SubBackward0>)
# Batch: 79/107, Time per batch: 306
# torch.Size([8, 100, 51])
# Batch: 80/107, Time per batch: 310
# torch.Size([8, 100, 51])
# Batch: 81/107, Time per batch: 313
# torch.Size([8, 100, 51])
# Batch: 82/107, Time per batch: 317
# torch.Size([8, 100, 51])
# Batch: 83/107, Time per batch: 321
# torch.Size([8, 100, 51])
# Batch: 84/107, Time per batch: 325
# torch.Size([8, 100, 51])
# Batch: 85/107, Time per batch: 329
# torch.Size([8, 100, 51])
# Batch: 86/107, Time per batch: 332
# torch.Size([8, 100, 51])
# Batch: 87/107, Time per batch: 336
# torch.Size([8, 100, 51])
# Batch: 88/107, Time per batch: 340
# torch.Size([8, 100, 51])
# Batch: 89/107, Time per batch: 344
# torch.Size([8, 100, 51])
# Batch: 90/107, Time per batch: 348
# torch.Size([8, 100, 51])
# Batch: 91/107, Time per batch: 351
# torch.Size([8, 100, 51])
# Batch: 92/107, Time per batch: 355
# torch.Size([8, 100, 51])
# Batch: 93/107, Time per batch: 359
# torch.Size([8, 100, 51])
# Batch: 94/107, Time per batch: 363
# torch.Size([8, 100, 51])
# Batch: 95/107, Time per batch: 366
# torch.Size([8, 100, 51])
# Batch: 96/107, Time per batch: 370
# torch.Size([8, 100, 51])
# Batch: 97/107, Time per batch: 374
# torch.Size([8, 100, 51])
# Batch: 98/107, Time per batch: 378
# torch.Size([8, 100, 51])
# Batch: 99/107, Time per batch: 381
# torch.Size([8, 100, 51])
# Batch: 100/107, Time per batch: 385
# torch.Size([8, 100, 51])
# Batch: 101/107, Time per batch: 389
# torch.Size([8, 100, 51])
# Batch: 102/107, Time per batch: 393
# torch.Size([8, 100, 51])
# Batch: 103/107, Time per batch: 397
# torch.Size([8, 100, 51])
# Batch: 104/107, Time per batch: 400
# torch.Size([8, 100, 51])
# Batch: 105/107, Time per batch: 404
# torch.Size([8, 100, 51])
# Batch: 106/107, Time per batch: 408
# Mean batch loss: 0.16637893689570027, Dis loss: 1.3829320624609973, Gen loss: 170.10602968875492
# Done.
# s2ag training epoch: 2
# torch.Size([8, 100, 51])
# Batch: 0/107, Time per batch: 4
# torch.Size([8, 100, 51])
# Batch: 1/107, Time per batch: 8
# torch.Size([8, 100, 51])
# Batch: 2/107, Time per batch: 12
# torch.Size([8, 100, 51])
# Batch: 3/107, Time per batch: 16
# torch.Size([8, 100, 51])
# Batch: 4/107, Time per batch: 19
# torch.Size([8, 100, 51])
# Batch: 5/107, Time per batch: 23
# torch.Size([8, 100, 51])
# Batch: 6/107, Time per batch: 27
# torch.Size([8, 100, 51])
# Batch: 7/107, Time per batch: 31
# torch.Size([8, 100, 51])
# Batch: 8/107, Time per batch: 35
# torch.Size([8, 100, 51])
# Batch: 9/107, Time per batch: 39
# torch.Size([8, 100, 51])
# Batch: 10/107, Time per batch: 43
# torch.Size([8, 100, 51])
# Batch: 11/107, Time per batch: 47
# torch.Size([8, 100, 51])
# Batch: 12/107, Time per batch: 51
# torch.Size([8, 100, 51])
# Batch: 13/107, Time per batch: 55
# torch.Size([8, 100, 51])
# Batch: 14/107, Time per batch: 59
# torch.Size([8, 100, 51])
# Batch: 15/107, Time per batch: 63
# torch.Size([8, 100, 51])
# Batch: 16/107, Time per batch: 67
# torch.Size([8, 100, 51])
# Batch: 17/107, Time per batch: 71
# torch.Size([8, 100, 51])
# Batch: 18/107, Time per batch: 75
# torch.Size([8, 100, 51])
# Batch: 19/107, Time per batch: 79
# torch.Size([8, 100, 51])
# Batch: 20/107, Time per batch: 83
# torch.Size([8, 100, 51])
# Batch: 21/107, Time per batch: 87
# torch.Size([8, 100, 51])
# Batch: 22/107, Time per batch: 91
# torch.Size([8, 100, 51])
# Batch: 23/107, Time per batch: 95
# torch.Size([8, 100, 51])
# Batch: 24/107, Time per batch: 99
# torch.Size([8, 100, 51])
# Batch: 25/107, Time per batch: 103
# torch.Size([8, 100, 51])
# Batch: 26/107, Time per batch: 106
# torch.Size([8, 100, 51])
# Batch: 27/107, Time per batch: 110
# torch.Size([8, 100, 51])
# Batch: 28/107, Time per batch: 114
# torch.Size([8, 100, 51])
# Batch: 29/107, Time per batch: 118
# torch.Size([8, 100, 51])
# Batch: 30/107, Time per batch: 121
# torch.Size([8, 100, 51])
# Batch: 31/107, Time per batch: 125
# torch.Size([8, 100, 51])
# Batch: 32/107, Time per batch: 129
# torch.Size([8, 100, 51])
# Batch: 33/107, Time per batch: 133
# torch.Size([8, 100, 51])
# Batch: 34/107, Time per batch: 136
# torch.Size([8, 100, 51])
# Batch: 35/107, Time per batch: 140
# torch.Size([8, 100, 51])
# Batch: 36/107, Time per batch: 144
# torch.Size([8, 100, 51])
# Batch: 37/107, Time per batch: 148
# torch.Size([8, 100, 51])
# Batch: 38/107, Time per batch: 151
# torch.Size([8, 100, 51])
# Batch: 39/107, Time per batch: 155
# torch.Size([8, 100, 51])
# Batch: 40/107, Time per batch: 159
# torch.Size([8, 100, 51])
# Batch: 41/107, Time per batch: 163
# torch.Size([8, 100, 51])
# Batch: 42/107, Time per batch: 166
# torch.Size([8, 100, 51])
# Batch: 43/107, Time per batch: 170
# torch.Size([8, 100, 51])
# Batch: 44/107, Time per batch: 174
# torch.Size([8, 100, 51])
# Batch: 45/107, Time per batch: 178
# torch.Size([8, 100, 51])
# Batch: 46/107, Time per batch: 181
# torch.Size([8, 100, 51])
# Batch: 47/107, Time per batch: 185
# torch.Size([8, 100, 51])
# Batch: 48/107, Time per batch: 189
# torch.Size([8, 100, 51])
# Batch: 49/107, Time per batch: 193
# torch.Size([8, 100, 51])
# Batch: 50/107, Time per batch: 196
# torch.Size([8, 100, 51])
# Batch: 51/107, Time per batch: 200
# torch.Size([8, 100, 51])
# Batch: 52/107, Time per batch: 204
# torch.Size([8, 100, 51])
# Batch: 53/107, Time per batch: 208
# torch.Size([8, 100, 51])
# Batch: 54/107, Time per batch: 211
# torch.Size([8, 100, 51])
# Batch: 55/107, Time per batch: 215
# torch.Size([8, 100, 51])
# Batch: 56/107, Time per batch: 219
# torch.Size([8, 100, 51])
# Batch: 57/107, Time per batch: 223
# torch.Size([8, 100, 51])
# Batch: 58/107, Time per batch: 226
# torch.Size([8, 100, 51])
# Batch: 59/107, Time per batch: 230
# torch.Size([8, 100, 51])
# Batch: 60/107, Time per batch: 234
# torch.Size([8, 100, 51])
# Batch: 61/107, Time per batch: 238
# torch.Size([8, 100, 51])
# Batch: 62/107, Time per batch: 241
# torch.Size([8, 100, 51])
# Batch: 63/107, Time per batch: 245
# torch.Size([8, 100, 51])
# Batch: 64/107, Time per batch: 249
# torch.Size([8, 100, 51])
# Batch: 65/107, Time per batch: 253
# torch.Size([8, 100, 51])
# Batch: 66/107, Time per batch: 256
# torch.Size([8, 100, 51])
# Batch: 67/107, Time per batch: 260
# torch.Size([8, 100, 51])
# Batch: 68/107, Time per batch: 264
# torch.Size([8, 100, 51])
# Batch: 69/107, Time per batch: 268
# torch.Size([8, 100, 51])
# Batch: 70/107, Time per batch: 271
# torch.Size([8, 100, 51])
# Batch: 71/107, Time per batch: 275
# torch.Size([8, 100, 51])
# Batch: 72/107, Time per batch: 279
# torch.Size([8, 100, 51])
# Batch: 73/107, Time per batch: 283
# torch.Size([8, 100, 51])
# Batch: 74/107, Time per batch: 286
# torch.Size([8, 100, 51])
# Batch: 75/107, Time per batch: 290
# torch.Size([8, 100, 51])
# Batch: 76/107, Time per batch: 294
# torch.Size([8, 100, 51])
# Batch: 77/107, Time per batch: 298
# torch.Size([8, 100, 51])
# Batch: 78/107, Time per batch: 301
# torch.Size([8, 100, 51])
# Batch: 79/107, Time per batch: 305
# torch.Size([8, 100, 51])
# Batch: 80/107, Time per batch: 309
# torch.Size([8, 100, 51])
# Batch: 81/107, Time per batch: 313
# torch.Size([8, 100, 51])
# Batch: 82/107, Time per batch: 316
# torch.Size([8, 100, 51])
# Batch: 83/107, Time per batch: 320
# torch.Size([8, 100, 51])
# Batch: 84/107, Time per batch: 324
# torch.Size([8, 100, 51])
# Batch: 85/107, Time per batch: 328
# torch.Size([8, 100, 51])
# Batch: 86/107, Time per batch: 331
# torch.Size([8, 100, 51])
# Batch: 87/107, Time per batch: 335
# torch.Size([8, 100, 51])
# Batch: 88/107, Time per batch: 339
# torch.Size([8, 100, 51])
# Batch: 89/107, Time per batch: 343
# torch.Size([8, 100, 51])
# Batch: 90/107, Time per batch: 346
# torch.Size([8, 100, 51])
# Batch: 91/107, Time per batch: 350
# torch.Size([8, 100, 51])
# Batch: 92/107, Time per batch: 354
# torch.Size([8, 100, 51])
# Batch: 93/107, Time per batch: 358
# torch.Size([8, 100, 51])
# Batch: 94/107, Time per batch: 361
# torch.Size([8, 100, 51])
# Batch: 95/107, Time per batch: 365
# torch.Size([8, 100, 51])
# Batch: 96/107, Time per batch: 369
# torch.Size([8, 100, 51])
# Batch: 97/107, Time per batch: 373
# torch.Size([8, 100, 51])
# Batch: 98/107, Time per batch: 376
# torch.Size([8, 100, 51])
# Batch: 99/107, Time per batch: 380
# torch.Size([8, 100, 51])
# Batch: 100/107, Time per batch: 384
# torch.Size([8, 100, 51])
# Batch: 101/107, Time per batch: 388
# torch.Size([8, 100, 51])
# Batch: 102/107, Time per batch: 391
# torch.Size([8, 100, 51])
# Batch: 103/107, Time per batch: 395
# torch.Size([8, 100, 51])
# Batch: 104/107, Time per batch: 399
# torch.Size([8, 100, 51])
# Batch: 105/107, Time per batch: 403
# torch.Size([8, 100, 51])
# Batch: 106/107, Time per batch: 407
# Mean batch loss: 0.15326629920262042, Dis loss: 1.379897161064861, Gen loss: 150.18352308897215
# Done.
# s2ag training epoch: 3
# torch.Size([8, 100, 51])
# Batch: 0/107, Time per batch: 4
# torch.Size([8, 100, 51])
# Batch: 1/107, Time per batch: 8
# torch.Size([8, 100, 51])
# Batch: 2/107, Time per batch: 12
# torch.Size([8, 100, 51])
# Batch: 3/107, Time per batch: 15
# torch.Size([8, 100, 51])
# Batch: 4/107, Time per batch: 19
# torch.Size([8, 100, 51])
# Batch: 5/107, Time per batch: 23
# torch.Size([8, 100, 51])
# Batch: 6/107, Time per batch: 27
# torch.Size([8, 100, 51])
# Batch: 7/107, Time per batch: 31
# torch.Size([8, 100, 51])
# Batch: 8/107, Time per batch: 34
# torch.Size([8, 100, 51])
# Batch: 9/107, Time per batch: 38
# torch.Size([8, 100, 51])
# Batch: 10/107, Time per batch: 42
# torch.Size([8, 100, 51])
# Batch: 11/107, Time per batch: 46
# torch.Size([8, 100, 51])
# Batch: 12/107, Time per batch: 49
# torch.Size([8, 100, 51])
# Batch: 13/107, Time per batch: 53
# torch.Size([8, 100, 51])
# Batch: 14/107, Time per batch: 57
# torch.Size([8, 100, 51])
# Batch: 15/107, Time per batch: 60
# torch.Size([8, 100, 51])
# Batch: 16/107, Time per batch: 64
# torch.Size([8, 100, 51])
# Batch: 17/107, Time per batch: 68
# torch.Size([8, 100, 51])
# Batch: 18/107, Time per batch: 72
# torch.Size([8, 100, 51])
# Batch: 19/107, Time per batch: 76
# torch.Size([8, 100, 51])
# Batch: 20/107, Time per batch: 79
# torch.Size([8, 100, 51])
# Batch: 21/107, Time per batch: 83
# torch.Size([8, 100, 51])
# Batch: 22/107, Time per batch: 87
# torch.Size([8, 100, 51])
# Batch: 23/107, Time per batch: 91
# torch.Size([8, 100, 51])
# Batch: 24/107, Time per batch: 94
# torch.Size([8, 100, 51])
# Batch: 25/107, Time per batch: 98
# torch.Size([8, 100, 51])
# Batch: 26/107, Time per batch: 102
# torch.Size([8, 100, 51])
# Batch: 27/107, Time per batch: 106
# torch.Size([8, 100, 51])
# Batch: 28/107, Time per batch: 109
# torch.Size([8, 100, 51])
# Batch: 29/107, Time per batch: 113
# torch.Size([8, 100, 51])
# Batch: 30/107, Time per batch: 117
# torch.Size([8, 100, 51])
# Batch: 31/107, Time per batch: 121
# torch.Size([8, 100, 51])
# Batch: 32/107, Time per batch: 124
# torch.Size([8, 100, 51])
# Batch: 33/107, Time per batch: 128
# torch.Size([8, 100, 51])
# Batch: 34/107, Time per batch: 132
# torch.Size([8, 100, 51])
# Batch: 35/107, Time per batch: 136
# torch.Size([8, 100, 51])
# Batch: 36/107, Time per batch: 139
# torch.Size([8, 100, 51])
# Batch: 37/107, Time per batch: 143
# torch.Size([8, 100, 51])
# Batch: 38/107, Time per batch: 147
# torch.Size([8, 100, 51])
# Batch: 39/107, Time per batch: 151
# torch.Size([8, 100, 51])
# Batch: 40/107, Time per batch: 154
# torch.Size([8, 100, 51])
# Batch: 41/107, Time per batch: 158
# torch.Size([8, 100, 51])
# Batch: 42/107, Time per batch: 162
# torch.Size([8, 100, 51])
# Batch: 43/107, Time per batch: 166
# torch.Size([8, 100, 51])
# Batch: 44/107, Time per batch: 169
# torch.Size([8, 100, 51])
# Batch: 45/107, Time per batch: 173
# torch.Size([8, 100, 51])
# Batch: 46/107, Time per batch: 177
# torch.Size([8, 100, 51])
# Batch: 47/107, Time per batch: 181
# torch.Size([8, 100, 51])
# Batch: 48/107, Time per batch: 184
# torch.Size([8, 100, 51])
# Batch: 49/107, Time per batch: 188
# torch.Size([8, 100, 51])
# Batch: 50/107, Time per batch: 192
# torch.Size([8, 100, 51])
# Batch: 51/107, Time per batch: 196
# torch.Size([8, 100, 51])
# Batch: 52/107, Time per batch: 199
# torch.Size([8, 100, 51])
# Batch: 53/107, Time per batch: 203
# torch.Size([8, 100, 51])
# Batch: 54/107, Time per batch: 207
# torch.Size([8, 100, 51])
# Batch: 55/107, Time per batch: 211
# torch.Size([8, 100, 51])
# Batch: 56/107, Time per batch: 214
# torch.Size([8, 100, 51])
# Batch: 57/107, Time per batch: 218
# torch.Size([8, 100, 51])
# Batch: 58/107, Time per batch: 222
# torch.Size([8, 100, 51])
# Batch: 59/107, Time per batch: 226
# torch.Size([8, 100, 51])
# Batch: 60/107, Time per batch: 229
# torch.Size([8, 100, 51])
# Batch: 61/107, Time per batch: 233
# torch.Size([8, 100, 51])
# Batch: 62/107, Time per batch: 237
# torch.Size([8, 100, 51])
# Batch: 63/107, Time per batch: 241
# torch.Size([8, 100, 51])
# Batch: 64/107, Time per batch: 244
# torch.Size([8, 100, 51])
# Batch: 65/107, Time per batch: 248
# torch.Size([8, 100, 51])
# Batch: 66/107, Time per batch: 252
# torch.Size([8, 100, 51])
# Batch: 67/107, Time per batch: 256
# torch.Size([8, 100, 51])
# Batch: 68/107, Time per batch: 259
# torch.Size([8, 100, 51])
# Batch: 69/107, Time per batch: 263
# torch.Size([8, 100, 51])
# Batch: 70/107, Time per batch: 267
# torch.Size([8, 100, 51])
# Batch: 71/107, Time per batch: 271
# torch.Size([8, 100, 51])
# Batch: 72/107, Time per batch: 274
# torch.Size([8, 100, 51])
# Batch: 73/107, Time per batch: 278
# torch.Size([8, 100, 51])
# Batch: 74/107, Time per batch: 282
# torch.Size([8, 100, 51])
# Batch: 75/107, Time per batch: 286
# torch.Size([8, 100, 51])
# Batch: 76/107, Time per batch: 289
# torch.Size([8, 100, 51])
# Batch: 77/107, Time per batch: 293
# torch.Size([8, 100, 51])
# Batch: 78/107, Time per batch: 297
# torch.Size([8, 100, 51])
# Batch: 79/107, Time per batch: 301
# torch.Size([8, 100, 51])
# Batch: 80/107, Time per batch: 305
# torch.Size([8, 100, 51])
# Batch: 81/107, Time per batch: 309
# torch.Size([8, 100, 51])
# Batch: 82/107, Time per batch: 312
# torch.Size([8, 100, 51])
# Batch: 83/107, Time per batch: 316
# torch.Size([8, 100, 51])
# Batch: 84/107, Time per batch: 320
# torch.Size([8, 100, 51])
# Batch: 85/107, Time per batch: 324
# torch.Size([8, 100, 51])
# Batch: 86/107, Time per batch: 328
# torch.Size([8, 100, 51])
# Batch: 87/107, Time per batch: 331
# torch.Size([8, 100, 51])
# Batch: 88/107, Time per batch: 335
# torch.Size([8, 100, 51])
# Batch: 89/107, Time per batch: 339
# torch.Size([8, 100, 51])
# Batch: 90/107, Time per batch: 343
# torch.Size([8, 100, 51])
# Batch: 91/107, Time per batch: 347
# torch.Size([8, 100, 51])
# Batch: 92/107, Time per batch: 350
# torch.Size([8, 100, 51])
# Batch: 93/107, Time per batch: 354
# torch.Size([8, 100, 51])
# Batch: 94/107, Time per batch: 358
# torch.Size([8, 100, 51])
# Batch: 95/107, Time per batch: 362
# torch.Size([8, 100, 51])
# Batch: 96/107, Time per batch: 366
# torch.Size([8, 100, 51])
# Batch: 97/107, Time per batch: 369
# torch.Size([8, 100, 51])
# Batch: 98/107, Time per batch: 373
# torch.Size([8, 100, 51])
# Batch: 99/107, Time per batch: 377
# torch.Size([8, 100, 51])
# Batch: 100/107, Time per batch: 381
# torch.Size([8, 100, 51])
# Batch: 101/107, Time per batch: 385
# torch.Size([8, 100, 51])
# Batch: 102/107, Time per batch: 389
# torch.Size([8, 100, 51])
# Batch: 103/107, Time per batch: 392
# torch.Size([8, 100, 51])
# Batch: 104/107, Time per batch: 396
# torch.Size([8, 100, 51])
# Batch: 105/107, Time per batch: 400
# torch.Size([8, 100, 51])
# Batch: 106/107, Time per batch: 404
# Mean batch loss: 0.1427681586034944, Dis loss: 1.373777889759741, Gen loss: 134.22223370988792
# Done.
# s2ag training epoch: 4
# torch.Size([8, 100, 51])
# Batch: 0/107, Time per batch: 4
# torch.Size([8, 100, 51])
# Batch: 1/107, Time per batch: 8
# torch.Size([8, 100, 51])
# Batch: 2/107, Time per batch: 12
# torch.Size([8, 100, 51])
# Batch: 3/107, Time per batch: 16
# torch.Size([8, 100, 51])
# Batch: 4/107, Time per batch: 20
# torch.Size([8, 100, 51])
# Batch: 5/107, Time per batch: 23
# torch.Size([8, 100, 51])
# Batch: 6/107, Time per batch: 27
# torch.Size([8, 100, 51])
# Batch: 7/107, Time per batch: 31
# torch.Size([8, 100, 51])
# Batch: 8/107, Time per batch: 35
# torch.Size([8, 100, 51])
# Batch: 9/107, Time per batch: 39
# torch.Size([8, 100, 51])
# Batch: 10/107, Time per batch: 42
# torch.Size([8, 100, 51])
# Batch: 11/107, Time per batch: 46
# torch.Size([8, 100, 51])
# Batch: 12/107, Time per batch: 50
# torch.Size([8, 100, 51])
# Batch: 13/107, Time per batch: 54
# torch.Size([8, 100, 51])
# Batch: 14/107, Time per batch: 58
# torch.Size([8, 100, 51])
# Batch: 15/107, Time per batch: 61
# torch.Size([8, 100, 51])
# Batch: 16/107, Time per batch: 65
# torch.Size([8, 100, 51])
# Batch: 17/107, Time per batch: 69
# torch.Size([8, 100, 51])
# Batch: 18/107, Time per batch: 73
# torch.Size([8, 100, 51])

# %%
s2ag_generator.pose
